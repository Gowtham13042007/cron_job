# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowtham13042007/cron_job/blob/main/K_Fold_Cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn import datasets
from sklearn import svm

iris = datasets.load_iris()
print(iris.data.shape)
# Out:
# (150, 4)

# %%
X_train,X_test,y_train,y_test = train_test_split(iris.data,iris.target,test_size=0.4,random_state=0)

clf=svm.SVC(kernel='linear',C=1).fit(X_train,y_train) #Large C means the model hates mistakes
clf.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %%
scores=cross_val_score(clf,iris.data,iris.target,cv=5)
print(scores)
print(scores.mean())
# Out:
# [0.96666667 1.         0.96666667 0.96666667 1.        ]
# 0.9800000000000001

# %%
clf=svm.SVC(kernel='poly',C=100000).fit(X_train,y_train) #Large C means the model hates mistakes and in poly the default degree is 3
clf.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %%
scores=cross_val_score(clf,iris.data,iris.target,cv=5)
print(scores)
print(scores.mean())
# Out:
# [0.96666667 0.93333333 0.86666667 0.93333333 1.        ]
# 0.9400000000000001

# %%
clf=svm.SVC(kernel='poly',degree=5,C=100000).fit(X_train,y_train) #Large C means the model hates mistakes
clf.score(X_test,y_test)
# Out:
# 0.95

# %%
scores=cross_val_score(clf,iris.data,iris.target,cv=5)
print(scores)
print(scores.mean())
# Out:
# [0.96666667 0.93333333 0.86666667 0.93333333 1.        ]
# 0.9400000000000001
