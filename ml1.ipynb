# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowtham13042007/cron_job/blob/main/ml1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
incomes=np.random.normal(27000,15000,10000)
print(incomes)
np.mean(incomes)
# Out:
# [18680.55214525 33156.08338604 27376.65870409 ... 45575.69472959
#  53610.64475417 35468.59942577]
# np.float64(26905.135579149075)

# %%
import matplotlib.pyplot as plt
plt.hist(incomes,bins=5,edgecolor='black')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.title('Histogram of Income')
plt.show()

# %%
np.median(incomes)
# Out:
# np.float64(26891.427803903156)

# %%
ages=np.random.randint(18,high=90,size=100)
print(ages)
# Out:
# [52 35 67 35 35 73 42 89 70 51 86 75 78 86 26 67 26 73 27 18 18 56 57 69
#  29 73 23 88 26 82 73 38 66 82 38 61 71 71 45 64 69 42 41 67 87 37 31 76
#  32 79 38 26 18 82 48 54 81 79 55 55 46 60 88 25 75 41 45 19 27 20 80 44
#  74 48 64 80 47 63 79 71 29 65 63 80 48 83 29 71 75 88 82 61 69 25 64 40
#  41 30 59 45]

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=np.int64(26), count=np.int64(4))

# %%
import numpy as np
import matplotlib.pyplot as plt

incomes=np.random.normal(100,20,10000)
plt.hist(incomes,bins=50,edgecolor='black')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.title('Histogram of Income')
plt.show()

# %%
print(np.mean(incomes))
print(np.median(incomes))
# Out:
# 99.82995130700021
# 99.5391456796068

# %%
import numpy as np
incomes=np.random.normal(100,20,10000)
print(np.var(incomes))
print(np.std(incomes))
# Out:
# 405.0285293503665
# 20.125320602424363

# %%
import numpy as np
import matplotlib.pyplot as plt

values=np.random.uniform(-10,10,100000)
print(np.std(values))
plt.hist(values,bins=50,edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Values')
plt.show()
# Out:
# 5.7683067393147125
