# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowtham13042007/cron_job/blob/main/t_test_and_p_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy import stats

A=np.random.normal(25,2,10000)
B=np.random.normal(26,5,10000)   #as the t test is negative it suggests that the B means is greater than A means

stats.ttest_ind(A,B)
# Out:
# TtestResult(statistic=np.float64(-17.176987448593927), pvalue=np.float64(1.1686682816694003e-65), df=np.float64(19998.0))

# %%
B=np.random.normal(25,5,10000)
stats.ttest_ind(A,B)
# Out:
# TtestResult(statistic=np.float64(0.4700974462262997), pvalue=np.float64(0.638290524928748), df=np.float64(19998.0))

# %%
stats.ttest_ind(A,A)    #df means nA+nA-2
# Out:
# TtestResult(statistic=np.float64(0.0), pvalue=np.float64(1.0), df=np.float64(19998.0))
